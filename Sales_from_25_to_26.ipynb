# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_excel("/content/Sales from 25 to 26.xlsx")

# %%
df.head(5)
# Out:
#   Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4  \
# 0    Billing  PROFIT CEN         DC         DV        Material
# 1  724888159  CPCEXPAMER         EX        NaN  CM540-BJU-K500
# 2  720291130  CPCEXPAMER         EX         CB    CP200-CAL-L5
# 3  720291133  CPCEXPAMER         EX         CB    CP200-CAL-L5
# 4  720291139  CPCEXPAMER         EX         CB    CP200-CAL-L5
#
#                                Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                    Material Description       Plnt       SOFF     CustNo
# 1  MANCOZEB  TECHNICAL (500 KG JUMBO BAG)       PSGM       CA02     875181
# 2  BESTPHOS (PROFEN 40%+CYPER 4%) - 5 LTR       PRPT       CA02     875218
# 3  BESTPHOS (PROFEN 40%+CYPER 4%) - 5 LTR       PRPT       CA02     875218
# 4  BESTPHOS (PROFEN 40%+CYPER 4%) - 5 LTR       PRPT       CA02     875218
#
#                          Unnamed: 9          Unnamed: 10 Unnamed: 11  \
# ...

# %%
df.columns = df.iloc[0]
df = df[1:].reset_index(drop=True)

# %%
df
# Out:
# 0       Billing  PROFIT CEN  DC   DV        Material  \
# 0     724888159  CPCEXPAMER  EX  NaN  CM540-BJU-K500
# 1     720291130  CPCEXPAMER  EX   CB    CP200-CAL-L5
# 2     720291133  CPCEXPAMER  EX   CB    CP200-CAL-L5
# 3     720291139  CPCEXPAMER  EX   CB    CP200-CAL-L5
# 4     720582610  CPCEXPAMER  EX   CB    CP200-CAL-L5
# ...         ...         ...  ..  ...             ...
# 1648  728663957  CPCEXPAMER  EX   CT  CM540-BJU-K500
# 1649  728664040  CPCEXPAMER  EX   CT  CM540-BJU-K500
# 1650  728703201  CPCEXPAMER  EX   CB   CM240-CHD-L35
# 1651  728703275  CPCEXPAMER  EX   CB   CM240-CHD-L35
# 1652  728740471  CPCEXPAMER  EX   CB   CM260-CHD-L20
#
# 0                       Material Description  Plnt  SOFF  CustNo  \
# 0     MANCOZEB  TECHNICAL (500 KG JUMBO BAG)  PSGM  CA02  875181
# 1     BESTPHOS (PROFEN 40%+CYPER 4%) - 5 LTR  PRPT  CA02  875218
# 2     BESTPHOS (PROFEN 40%+CYPER 4%) - 5 LTR  PRPT  CA02  875218
# ...

# %%
df.count()
# Out:
# 0
# Billing                 1653
# PROFIT CEN              1653
# DC                      1653
# DV                      1620
# Material                1653
# Material Description    1653
# Plnt                    1653
# SOFF                    1653
# CustNo                  1653
# Customer Name           1653
# Inv Date                1653
# Qty                     1653
# Amount                  1653
# USD                     1649
# Crs                     1652
# YEAR                    1653
# MON                     1653
# Destination Country     1653
# Region                  1653
# Channel                 1653
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1653 entries, 0 to 1652
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Billing               1653 non-null   object
#  1   PROFIT CEN            1653 non-null   object
#  2   DC                    1653 non-null   object
#  3   DV                    1620 non-null   object
#  4   Material              1653 non-null   object
#  5   Material Description  1653 non-null   object
#  6   Plnt                  1653 non-null   object
#  7   SOFF                  1653 non-null   object
#  8   CustNo                1653 non-null   object
#  9   Customer Name         1653 non-null   object
#  10  Inv Date              1653 non-null   object
#  11  Qty                   1653 non-null   object
#  12  Amount                1653 non-null   object
#  13  USD                   1649 non-null   object
#  14  Crs                   1652 non-null   object
# ...

# %%
df.describe()
# Out:
# /tmp/ipykernel_5592/3627053830.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   df.describe()
# 0         Billing  PROFIT CEN    DC    DV        Material  \
# count        1653        1653  1653  1620            1653
# unique        747           3     2     2              42
# top     723901738  CPCEXPAMER    EX    CT  CM540-BJU-K500
# freq           70        1576  1631  1062             863
#
# 0                         Material Description  Plnt  SOFF  CustNo  \
# count                                     1653  1653  1653    1653
# unique                                      51     5     2      49
# top     MANCOZEB  TECHNICAL (500 KG JUMBO BAG)  PSGM  CA02  875155
# freq                                       855   791  1632     422
#
# ...

# %%
df.isnull().sum()
# Out:
# 0
# Billing                  0
# PROFIT CEN               0
# DC                       0
# DV                      33
# Material                 0
# Material Description     0
# Plnt                     0
# SOFF                     0
# CustNo                   0
# Customer Name            0
# Inv Date                 0
# Qty                      0
# Amount                   0
# USD                      4
# Crs                      1
# YEAR                     0
# MON                      0
# Destination Country      0
# Region                   0
# Channel                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 0
# Billing                 0
# PROFIT CEN              0
# DC                      0
# DV                      0
# Material                0
# Material Description    0
# Plnt                    0
# SOFF                    0
# CustNo                  0
# Customer Name           0
# Inv Date                0
# Qty                     0
# Amount                  0
# USD                     0
# Crs                     0
# YEAR                    0
# MON                     0
# Destination Country     0
# Region                  0
# Channel                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1615 entries, 1 to 1651
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Billing               1615 non-null   object
#  1   PROFIT CEN            1615 non-null   object
#  2   DC                    1615 non-null   object
#  3   DV                    1615 non-null   object
#  4   Material              1615 non-null   object
#  5   Material Description  1615 non-null   object
#  6   Plnt                  1615 non-null   object
#  7   SOFF                  1615 non-null   object
#  8   CustNo                1615 non-null   object
#  9   Customer Name         1615 non-null   object
#  10  Inv Date              1615 non-null   object
#  11  Qty                   1615 non-null   object
#  12  Amount                1615 non-null   object
#  13  USD                   1615 non-null   object
#  14  Crs                   1615 non-null   object
# ...

# %%
### Data Cleaning

# %%
df['Inv Date'] = pd.to_datetime(df['Inv Date'], errors='coerce')

# %%
df['Qty'] = pd.to_numeric(df['Qty'], errors='coerce')
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
df['USD'] = pd.to_numeric(df['USD'], errors='coerce')

# %%
df['Amount'].sum()
# Out:
# np.float64(11054190325.43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1615 entries, 1 to 1651
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Billing               1615 non-null   object
#  1   PROFIT CEN            1615 non-null   object
#  2   DC                    1615 non-null   object
#  3   DV                    1615 non-null   object
#  4   Material              1615 non-null   object
#  5   Material Description  1615 non-null   object
#  6   Plnt                  1615 non-null   object
#  7   SOFF                  1615 non-null   object
#  8   CustNo                1615 non-null   object
#  9   Customer Name         1615 non-null   object
#  10  Inv Date              1615 non-null   datetime64[ns]
#  11  Qty                   1615 non-null   float64
#  12  Amount                1615 non-null   float64
#  13  USD                   1615 non-null   float64
# ...

# %%
df['Amount'].sum()
# Out:
# np.float64(11054190325.43)

# %%
df.groupby('Plnt')['Amount'].sum().sort_values(ascending=False)
# Out:
# Plnt
# PSGM    4.715680e+09
# PDHJ    3.197104e+09
# PANK    1.697319e+09
# PSTW    9.643607e+08
# PRPT    4.797268e+08
# Name: Amount, dtype: float64

# %%
df.groupby('Customer Name')['Amount'].sum().sort_values(ascending=False)
# Out:
# Customer Name
# TECNOMYL S.A                           2.086122e+09
# ADAMA CELSIUS B.V                      1.612140e+09
# DISTRIBUIDORA INQUISA , S.A            1.332689e+09
# IHARABRAS SA INDUSTRIAS QUIMICAS       1.049785e+09
# LEADER GLOBAL SOLUTIONS LLC            4.493290e+08
# AMAGGI EXPORTACAO E IMPORTACAO LTDA    4.461128e+08
# ADAMA BRASIL S/A                       3.195055e+08
# CROPCHEM LTDA                          2.855075e+08
# CHD'S AGROCHEMICALS S.A.I.C.           2.715836e+08
# NUFARM GRUPO MEXICO, S DE RL DE CV     2.608295e+08
# CHDS DO BRASIL COMERCIO DE INSUMOS     2.386904e+08
# SOLUS INDUSTRIA QUIMICA LTDA           2.095886e+08
# AT AGRO COMPANY LIMITED                1.982463e+08
# INTEROC S.A.                           1.948343e+08
# GLOBAL FERTILIZER TRADING CO LTD       1.603856e+08
# QUIMICA LUCAVA, SA DE CV               1.483287e+08
# PERTERRA TRADING SA                    1.464157e+08
# SIPCAM NICHINO BRASIL S/A              1.198182e+08
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['Qty'].hist()
plt.show()

# %%
import seaborn as sns

sns.boxplot(x=df['Amount'])
# Out:
# <Axes: xlabel='Amount'>

# %%
df['Price_per_unit'] = df['Amount'] / df['Qty']
